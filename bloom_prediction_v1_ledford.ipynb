# %%
import pandas as pd

# %%
cherry_dc = pd.read_csv('Q_blooms_dc.csv')
temps_dc = pd.read_csv('Q_temps_dc.csv')
dc_Predtemps_feb = pd.read_csv('dcPredictedTemps_February_20Thru28.csv')
dc_Predtemps_march = pd.read_csv('dcPredictedTemps_March_2026.csv')
dc_Predtemps_april = pd.read_csv("dcPredictedTemps_May_2026.csv")
full_dc = pd.concat([cherry_dc, temps_dc, dc_Predtemps_feb, dc_Predtemps_march, dc_Predtemps_april], ignore_index=True)
full_dc.to_csv('dc_cherryAndtemps_full.csv')
print(full_dc.tail())
# Out:
#        year bloom_date  bloom_doy date   tmax   tmin    temp  Unnamed: 0
# 30419   NaN        NaN        NaN  NaN  23.89  11.67  23.615        18.0
# 30420   NaN        NaN        NaN  NaN  23.33  17.22  28.885        19.0
# 30421   NaN        NaN        NaN  NaN  22.78  11.67  23.060        20.0
# 30422   NaN        NaN        NaN  NaN  25.56  10.00  22.780        21.0
# 30423   NaN        NaN        NaN  NaN  22.22  11.67  22.780        22.0
