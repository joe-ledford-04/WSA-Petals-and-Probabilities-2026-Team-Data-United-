# %%
import pandas as pd

# %%
cherry_dc = pd.read_csv('Q_blooms_dc.csv')
temps_dc = pd.read_csv('Q_temps_dc.csv')
full_dc = pd.concat([cherry_dc, temps_dc])
print(cherry_dc.head())
print(temps_dc.head())
# Out:
#    year  bloom_date  bloom_doy
# 0  1942  1942-04-05         95
# 1  1943  1943-04-04         94
# 2  1944  1944-04-09        100
# 3  1945  1945-03-20         79
# 4  1946  1946-03-23         82
#    year        date  tmax  tmin  temp
# 0  1942  1942-01-01  11.7   3.3   7.5
# 1  1942  1942-01-02  15.0   0.6   7.8
# 2  1942  1942-01-03   4.4  -2.2   1.1
# 3  1942  1942-01-04   4.4  -0.6   1.9
# 4  1942  1942-01-05   2.2  -7.2  -2.5
